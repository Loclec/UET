# %% [markdown]
# ### Xep loai hoc luc

# %%
a= float(input("Nhap diem trung binh cua ban"))
if a >= 8.0:
    print("Ban xep loai GIOI")
elif a >= 6.5:
    print("Ban xep loai KHA")
elif a >= 5.0: 
    print("Ban xep loai TB")
elif a < 5:
    print("Ban xep loai YEU")
# Out:
# Ban xep loai KHA
