# %% [markdown]
# ##                                                  MỘT SỐ BTVN

# %% [markdown]
# ### B1

# %%
n= int(input("Nhap so nguyen n: "))
m= n*2
print(f"so gap doi {n} la {m}")
# Out:
# so gap doi 2 la 4

# %% [markdown]
# ### B2

# %%
ab= map(int, input("Nhap chieu dai a va chieu rong b: ").split())
a, b= ab
c= a*b - 3.14*(a**2/4) 
print(f"Dien tich con lai de trong cay la: {c}")
# Out:
# Dien tich con lai de trong cay la: 2.86

# %% [markdown]
# ### B3

# %%
a=input("Nhap mot ky tu: ")
if a.islower():
    b= a.upper()
    print(f"Chu cai in hoa la: {b} ")
else:
    b= a.lower()
    print(f"Chu cai in thuong la: {b} ")
# Out:
# Chu cai in hoa la:A

# %% [markdown]
# ### B4

# %%
c=input("Nhap mot ky tu: ")
if c.isalpha():
    print(f"{c} la ky tu alphabet")
else:
    print(f"{c} khong phai la ky tu alphabet")
# Out:
# @ khong phai la ky tu alphabet

# %% [markdown]
# ### B5

# %%
c= input("Nhap mot chu cai in hoa: ")
if c.isupper():
    d= ord(c)-1
    if d < ord('A'):
        d= ord('Z')
    print(f"Ky tu truoc do la: {chr(d).lower()}")
else: 
    print("Vui long nhap chu cai in hoa")
# Out:
# Ky tu truoc do la: a

# %% [markdown]
# ### B6

# %%
abc= map(int, input("Nhap do dai 3 canh tam giac(cach boi dau cach): ").split())
a, b, c= abc
if a+b>c and a+c>b and b+c>a:
    print("3 canh tren tao thanh 1 tam giac")
else:
    print("3 canh tren khong tao thanh 1 tam giac")
# Out:
# 3 canh tren khong tao thanh 1 tam giac

# %% [markdown]
# ### B7

# %%
a=input("Nhap ki tu thuong(do dai lon hon 20): ")
if len(a)>=20 and a.islower():
    print(f"Ky tu thu 5: {a[4]}")
    print(f"Ky tu thu 9: {a[8]}")
else:
    print("Vui long nhap chuoi gom cac ky tu thuong va do dai >=20")
# Out:
# Ky tu thu 5: a
# Ky tu thu 9: 2

# %% [markdown]
# ### B8

# %%
chu_ho= input("Nhap chu ho: ")
print(f"Ho va ten: {chu_ho}")
thang_trc=int(input("Nhap chi so thang truoc: "))
thang_nay=int(input("Nhap chi so thang nay: "))
so_dien= thang_nay - thang_trc
if 0<= so_dien <=50:
    tien_dien_bac_1= so_dien*1984
    print(f"Tien phai tra la: {(tien_dien_bac_1)*8/100 + tien_dien_bac_1} VND")
if 51<= so_dien <=100:
    tien_dien_bac_2= (so_dien - 50)*2050 + 50*1984
    print(f"Tien phai tra la: {(tien_dien_bac_2)*8/100 + tien_dien_bac_2 } VND")
if 101<= so_dien <=200:
    tien_dien_bac_3= (so_dien - 100)*2380 + 50*2050 + 50*1984
    print(f"Tien phai tra la: {(tien_dien_bac_3)*8/100 + tien_dien_bac_3} VND")
if 201<= so_dien <=300:
    tien_dien_bac_4= (so_dien - 200)*2998 + 100*2380 + 50*2050 + 50*1984
    print(f"Tien phai tra la: {(tien_dien_bac_4)*8/100 + tien_dien_bac_4} VND")
if 301<= so_dien <=400:
    tien_dien_bac_5= (so_dien - 300)*3350 + 100*2998 + 100*2380 + 50*2050 + 50*1984
    print(f"Tien phai tra la: {(tien_dien_bac_5)*8/100 + tien_dien_bac_5} VND")
if so_dien >400:
    tien_dien_bac_6= (so_dien - 400)*3460 + 100*3350 + 100*2998 + 100*2380 + 50*2050 + 50*1984
    print(f"Tien phai tra la: {(tien_dien_bac_6)*8/100 + tien_dien_bac_6} VND")
# Out:
# Ho va ten: a
# Tien phai tra la: 1855504.8 VND

# %% [markdown]
# ## MỘT SỐ BT KHÁC

# %% [markdown]
# ### 1

# %%
a=int(input("Nhap day so ngau nhien: "))
if a%2==0:
    print(f"{a} la so chan")
else:
    print(f"{a} la so le")
# Out:
# 22232131231210 la so chan

# %% [markdown]
# ### 2

# %%
a=int(input("Nhap so nguyen: "))
if a%5==0:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### 3

# %%
a=int(input("Nhap so nguyen: "))
if a%3==0 and a%5==0:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### 4

# %%
a=int(input("Nhap tuoi cua ban: "))
if a>=18:
    print("Ban da du tuoi de di bau cu")
else:
    print("Ban chua du tuoi de di bau cu")

# %% [markdown]
# ### 5

# %%
a=int(input("Nhap so thu nhat: "))
b=int(input("Nhap so thu hai: "))
if a>b:
    print(f"So lon hon la: {a}")
if b>a:
    print(f"So lon hon la: {b}")
if a==b:
    print("Hai so bang nhau")
# Out:
# Hai so bang nhau

# %% [markdown]
# ### 6

# %%
a=input("Nhap ky tu ngau nghien: ")
if a.isalpha():
    print(f" '{a}' la chu cai")
if a.isnumeric():
    print(f"'{a}' la chu so")
# Out:
#  'a' la chu cai

# %% [markdown]
# ### 7

# %%
i=int(input("Nhap diem cua ban: "))
if i>=8:
    print("Xep loai Gioi") 
if i>=6.5 and i<8:
    print("Xep loai Kha")
if i>=5 and i<6.5:
    print("Xep loai Trung Binh")
if i<5:
    print("Xep loai Yeu")
# Out:
# Xep loai Yeu

# %% [markdown]
# ### 8

# %%
a=int(input("Nhap nam can kiem tra: "))
if a%4==0 or a%400==0 and a%100!=0:
    print(f"{a} la nam nhuan")
else:
    print(f"{a} khong phai la nam nhuan")
# Out:
# 2024 la nam nhuan

# %% [markdown]
# ### 9

# %%
a=int(input("Nhap so nguyen tu 1 den 9: "))
match a:
    case 1:
        print("Mot")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bon")
    case 5:
        print("Nam")
    case 6:
        print("Sau")
    case 7:
        print("Bay")
    case 8:
        print("Tam")
    case 9:
        print("Chin")
    case _:
        print("So khong hop le")
# Out:
# Chin

# %% [markdown]
# ### 10

# %%
a=int(input("Nhap diem thi: "))
match a:
    case a if a>=4:
        print("Qua mon")
    case _:
        print("Hoc lai")
# Out:
# Hoc lai

# %% [markdown]
# ### 11

# %%
a=int(input("Nhap nam sinh cua ban: "))
match a:
    case a if 2025 - a >=18:
        print("Ban da du 18 tuoi")
    case a if 2025 - a <18:
        print("Ban chua du 18 tuoi")
# Out:
# Ban da du 18 tuoi
